# %% [markdown]
# # <img src="/files/downloads/Picture2.png" style="width:570px;height:330px; display:block;margin-left:auto;margin-right: auto;">

# %% [markdown]
# <img src="/files/downloads/Picture3.png" style="width:570px;height:330px; display:block;margin-left:auto;margin-right: auto;">

# %% [markdown]
# <img src="/files/downloads/Picture1.png" style="float:left;width:367px;height:243px;">
#
#
#    # Hi I am Mohamed

# %% [markdown]
# # WHY PYTHON?!
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Python Applications
# • Build a website<br>
# • Develop a game<br>
# • Perform Computer Vision (Facilities like face detection and color detection)<br>
# • Implement Machine Learning (Give a computer the ability to learn)<br>
# • Enable Robotics<br>
# • Perform Web Scraping (Harvest data from websites)<br>
# • Perform Data Analysis<br>
# • Automate a web browser<br>
# • Perform Scripting<br>
# • Perform Scientific Computing<br>
# • Build Artificial Intelligence<br>

# %% [markdown]
# ### Aps created with Python
# <img src="/files/downloads/dropbox-logo.png" style="float:left;width:367px;height:243px;">
# <img src="/files/downloads/717.jpg" style="float:left;width:367px;height:243px;">
# <img src="/files/downloads/download.png" style="display=block;float:left;width:367px;height:243px;">

# %% [markdown]
# # IDE
# - An integrated development environment (IDE) is a software application that provides comprehensive facilities to computer programmers for software development.
# <img src="/files/downloads/1-LPnY8nOLg4S6_TG0DEXwsg-1.png">

# %% [markdown]
# # Comment
#
# • When it comes to comments, you should use the hash symbol ( # ) to start them. However, this hash symbol should not be within a string literal. Also, the characters after it towards the end of the line should be included in the comment. In Python, comments are not recognized by the interpreter. To help you understand this concept further, take a look at

# %%
# This is the first comment

# %% [markdown]
# ### Escape Sequences
# •The newline character n is called an escape sequence Escape sequences are
# the way Python expresses special characters, such as the tab, the newline,
# and the backspace (delete key), as literals
# ![image.png](attachment:image.png)

# %% [markdown]
# # Reading Input

# %%
person = input("What is your name?")
# Out:
# What is your name?Doaa

# %%
value = input("Enter an integer:")

# %% [markdown]
# # Print Output

# %%
print("Hello Doaa")
# Out:
# Hello Doaa

# %%
country = input("Which country do you live in?")
print("I live in{0}".format(country))
# Out:
# Which country do you live in?
# I live in

# %%
first_name= "Doaa"
last_name= "Mostafa"
Grade=90
print( "Hello, %s %s %d" % (first_name , last_name,Grade ))

# %% [markdown]
# # Variables
# • Variables are names given to data that we need to store and manipulate in our programs. <br>
# • A variable name in Python can only contain letters (a - z, A - B), numbers or underscores (_). However, the first character cannot be a number. Hence, you can name your variables userName, user_name or userName2 but not 2userName.<br>
# In addition, there are some reserved words that you cannot use as a variable name because they already have preassigned meanings in Python. These reserved words include words like print, input, if , while etc.<br>

# %% [markdown]
# • Camel case is the practice of writing compound words with mixed casing (e.g. thisIsAVariableName). This is the convention that we’ll be using in the rest of the book. Alternatively, another common practice is to use underscores (_) to separate the words. If you prefer, you can name your variables like this: this_is_a_variable_name.<br>
# • Variable types don’t need to be declared<br>

# %%
x = True # valid

# %%
_y = True # valid

# %%
x = False # starts with numeral

# %%
$y = False # starts with symbol
# Out:
#   File "<ipython-input-19-50101988d602>", line 1
#     $y = False # starts with symbol
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### Python Keywords are not allowed as variable names.
# ![image.png](attachment:image.png)

# %% [markdown]
# # Assigning Values to Variables
# •The general format for assigning values to variables is as follows:<br>
# variable_name = expression<br>
# Single assignment:<br>
# X=100<br>
# X=hundred<br>
# Multi assignment:<br>
# X,Y=3,4<br>
# X=Y=Z=2<br>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <img src="/files/downloads/pyhon3.png" style="float:left;width:450px;height:300px;">
# <img src="/files/downloads/unnamed.png" style="float:right;width:450px;height:300px;">

# %% [markdown]
# # String
# refers to text.

# %%
userName = 'Peter', userSpouseName = "Janet", userAge= '30'
# Out:
#   File "<ipython-input-20-5519531b6fd3>", line 1
#     userName = 'Peter', userSpouseName = "Janet", userAge= '30'
#                ^
# SyntaxError: cannot assign to literal

# %%
"Peter" + "Lee"
# Out:
# 'PeterLee'

# %% [markdown]
# <img src="/files/downloads/File-operations (1).png" style="float:left;width:500px;height:370px;">

# %% [markdown]
# ### open() function
# The open() function is used to open a file in a particular mode.<br>
# It basically creates a file object which can be used for further manipulations.<br>
# Different modes for opening a file:<br>
# r: Read<br>
# w: Write<br>
# a: Append<br>
# r+: Read and Write<br>
# Initially, we need to create a file and place it in the same directory as of the script.<br>
# Demo.txt<br>
# Welcome to the programming world!<br>
# Execute_file.py

# %%
open(file_name, mode)

# %% [markdown]
# ### read() function
# The read() function is used to read the contents of the file. To achieve the same, we need to open a file in the read mode.

# %%
demo_file = open("Demo.txt", "r")
print(demo_file.read())
demo_file.close()

# %% [markdown]
# ### write() function
# The write() function is used to write to a file and make changes to it.

# %%
demo_file = open('Demo.txt','w')
demo_file.write("Hello Everyone!.\n")
demo_file.write("Engineering Discipline.")
demo_file.close()

# %%
demo_file = open('Demo.txt','a')
demo_file.write("\nStatement added to the end of the file..")
demo_file.close()

# %% [markdown]
# ### split() function
# The split() function is used to split lines within a file. It splits up as soon as it encounters space in the script.<br>
# Demo.txt<br>
# Hello Everyone!.<br>
# Engineering Discipline.<br>
# Statement added to the end of the file..<br>
# Execute_file.py<br>

# %%
open("Demo.txt", "r") as demo_file:
    demo_data = demo_file.readlines()
    for line in demo_data:
        result = line.split()
        print(result)

# %% [markdown]
# ### close() function
# The close() function is used to close a particular file post manipulations on it.<br>
#
# After writing to a file, if we do not call the close() method, all the data written to the file will not be saved in it.<br>

# %% [markdown]
# ### rename() function
# The os module provides the rename() method to change the name of the particular file.

# %% [markdown]
# ### remove() method
# The os module provides the remove() method to delete the file given as input.
